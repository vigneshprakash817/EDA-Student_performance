# %%
#import required libory
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Student_performance_data _.csv') #load / read dataset

# %%
data # Show data
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df=pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
df.shape
# Out:
# (2392, 15)

# %%
df.columns # Find the column names
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
df.isnull().sum() #Handling missing values
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
df.isna().sum() # find the NA
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
df.duplicated().sum() # find the Duplicates
# Out:
# np.int64(0)

# %%
df.dtypes # find the data types
# Out:
# StudentID              int64
# Age                    int64
# Gender                 int64
# Ethnicity              int64
# ParentalEducation      int64
# StudyTimeWeekly      float64
# Absences               int64
# Tutoring               int64
# ParentalSupport        int64
# Extracurricular        int64
# Sports                 int64
# Music                  int64
# Volunteering           int64
# GPA                  float64
# GradeClass           float64
# dtype: object

# %%
uni=np.unique(df['StudentID']) # Find unique value

# %%
uni
# Out:
# array([1001, 1002, 1003, ..., 3390, 3391, 3392], shape=(2392,))

# %%
g_cnt=df['Gender'].value_counts() # Gender count

# %%
g_cnt
# Out:
# Gender
# 1    1222
# 0    1170
# Name: count, dtype: int64

# %%
total_students = df.shape[0]

# %%
df['TotalStudents'] = total_students # total students

# %%
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
#Line chart

plt.plot(g_cnt.index,g_cnt.values)
plt.title('Gender wise total_students',fontdict={'fontsize':20,'fontname':'arial','fontweight':'bold','color':'blue'})
plt.xlabel('Gender')
plt.ylabel('total_students')
plt.grid(True)
plt.show()

# %%
#Bar Chart
plt.bar(df['Ethnicity'],df['Absences'])
plt.title('Ethnicity wise Absences',fontdict={'fontsize':15,'fontname':'arial','fontweight':'bold','color':'Yellow'})
plt.xlabel('Ethnicity')
plt.ylabel('Absences')
plt.grid(True)
plt.show()

# %%
#Histogram Chart
plt.hist(df['Age'],bins=3)
plt.title('Age wise Bin',fontdict={'fontsize':20,'fontname':'Cambria','fontweight':'bold','color':'Brown'})
plt.xlabel('Bin')
plt.ylabel('Age')
plt.grid(True)
plt.show()

# %%
#scatterplot chart
sns.scatterplot(x='ParentalSupport',y='GPA',data=data)
plt.title('ParentalSupport Wise GPA',fontdict={'fontsize':20,'fontname':'Cambria','fontweight':'bold','color':'Brown'})
# Out:
# Text(0.5, 1.0, 'ParentalSupport Wise GPA')

# %%
# Pie Chart
plt.pie(g_cnt,labels=g_cnt.values)
plt.title('Gender wise Count',fontdict={'fontsize':20,'fontname':'arial','fontweight':'bold','color':'blue'})
plt.grid(True)
plt.show()
plt.figure(figsize=(8,6))

# %%
#Seaborn---Line Chart
sns.lineplot(x='Age',y='Absences',data=data)
plt.title('Age wise Absences',fontdict={'fontsize':16,'fontname':'Cambria','fontweight':'bold','color':'blue'})
# Out:
# Text(0.5, 1.0, 'Age wise Absences')

# %%
#Scatterplot chart
sns.scatterplot(x='Ethnicity',y='StudyTimeWeekly',data=data)
plt.title('Ethnicity Wise StudyTimeWeekly',fontdict={'fontsize':20,'fontname':'arial','fontweight':'bold','color':'blue'})
# Out:
# Text(0.5, 1.0, 'Ethnicity Wise StudyTimeWeekly')

# %%
#Bar chart
sns.barplot(x='Gender',y=g_cnt,data=data)
plt.title('Gender Wise Student count',fontdict={'fontsize':20,'fontname':'arial','fontweight':'bold','color':'Brown'})
# Out:
# Text(0.5, 1.0, 'Gender Wise Student count')

# %%
#Histogram chart
sns.histplot(data=data,x='GPA',bins=5,kde=True)
plt.title('GPA Wise Bin',fontdict={'fontsize':20,'fontname':'arial','fontweight':'bold','color':'red'})
# Out:
# Text(0.5, 1.0, 'GPA Wise Bin')
